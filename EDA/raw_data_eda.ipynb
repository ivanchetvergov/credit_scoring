# %%
import pandas as pd
import numpy as np

# %%
# Load dataset
df = pd.read_csv('../data/raw/application_train.csv')

# %%
print("shape:", df.shape)
print("memory (MB):", df.memory_usage(deep=True).sum() / 1024**2)
print("\nColumns sample:", df.columns.tolist()[:20])
# Out:
# shape: (307511, 122)
# memory (MB): 504.98532581329346
#
# Columns sample: ['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION']

# %%
missing = df.isna().mean().sort_values(ascending=False)
unique_counts = df.nunique().sort_values()
print("\nTop missing columns:\n", missing.head(20))
print("\nColumns with few uniques (<=5):\n", unique_counts[unique_counts <= 5].head(40))
print("\nHigh-cardinality columns (>50 uniques):\n", unique_counts[unique_counts > 50].head(40))
# Out:
# Top missing columns:
#  COMMONAREA_MEDI             0.698723
# COMMONAREA_AVG              0.698723
# COMMONAREA_MODE             0.698723
# NONLIVINGAPARTMENTS_MODE    0.694330
# NONLIVINGAPARTMENTS_AVG     0.694330
# NONLIVINGAPARTMENTS_MEDI    0.694330
# FONDKAPREMONT_MODE          0.683862
# LIVINGAPARTMENTS_MODE       0.683550
# LIVINGAPARTMENTS_AVG        0.683550
# LIVINGAPARTMENTS_MEDI       0.683550
# FLOORSMIN_AVG               0.678486
# FLOORSMIN_MODE              0.678486
# FLOORSMIN_MEDI              0.678486
# YEARS_BUILD_MEDI            0.664978
# YEARS_BUILD_MODE            0.664978
# YEARS_BUILD_AVG             0.664978
# OWN_CAR_AGE                 0.659908
# LANDAREA_MEDI               0.593767
# LANDAREA_MODE               0.593767
# LANDAREA_AVG                0.593767
# dtype: float64
#
# Columns with few uniques (<=5):
#  LIVE_CITY_NOT_WORK_CITY        2
# FLAG_DOCUMENT_18               2
# FLAG_DOCUMENT_14               2
# FLAG_MOBIL                     2
# FLAG_EMP_PHONE                 2
# FLAG_WORK_PHONE                2
# FLAG_CONT_MOBILE               2
# FLAG_PHONE                     2
# FLAG_EMAIL                     2
# FLAG_DOCUMENT_15               2
# FLAG_DOCUMENT_16               2
# FLAG_DOCUMENT_17               2
# EMERGENCYSTATE_MODE            2
# REG_CITY_NOT_WORK_CITY         2
# REG_CITY_NOT_LIVE_CITY         2
# REG_REGION_NOT_LIVE_REGION     2
# FLAG_DOCUMENT_19               2
# REG_REGION_NOT_WORK_REGION     2
# FLAG_DOCUMENT_20               2
# FLAG_DOCUMENT_13               2
# TARGET                         2
# NAME_CONTRACT_TYPE             2
# FLAG_DOCUMENT_2                2
# FLAG_OWN_CAR                   2
# FLAG_OWN_REALTY                2
# FLAG_DOCUMENT_3                2
# FLAG_DOCUMENT_4                2
# FLAG_DOCUMENT_5                2
# FLAG_DOCUMENT_6                2
# FLAG_DOCUMENT_7                2
# FLAG_DOCUMENT_8                2
# FLAG_DOCUMENT_9                2
# FLAG_DOCUMENT_10               2
# FLAG_DOCUMENT_11               2
# FLAG_DOCUMENT_12               2
# FLAG_DOCUMENT_21               2
# LIVE_REGION_NOT_WORK_REGION    2
# REGION_RATING_CLIENT           3
# CODE_GENDER                    3
# REGION_RATING_CLIENT_W_CITY    3
# dtype: int64
#
# High-cardinality columns (>50 uniques):
#  ORGANIZATION_TYPE                 58
# OWN_CAR_AGE                       62
# REGION_POPULATION_RELATIVE        81
# YEARS_BUILD_AVG                  149
# YEARS_BUILD_MEDI                 151
# YEARS_BUILD_MODE                 154
# NONLIVINGAPARTMENTS_MODE         167
# NONLIVINGAPARTMENTS_MEDI         214
# YEARS_BEGINEXPLUATATION_MODE     221
# YEARS_BEGINEXPLUATATION_MEDI     245
# ELEVATORS_AVG                    257
# ENTRANCES_AVG                    285
# YEARS_BEGINEXPLUATATION_AVG      285
# FLOORSMIN_AVG                    305
# NONLIVINGAPARTMENTS_AVG          386
# FLOORSMAX_AVG                    403
# LIVINGAPARTMENTS_MODE            736
# APARTMENTS_MODE                  760
# EXT_SOURCE_3                     814
# AMT_GOODS_PRICE                 1002
# LIVINGAPARTMENTS_MEDI           1097
# APARTMENTS_MEDI                 1148
# LIVINGAPARTMENTS_AVG            1868
# APARTMENTS_AVG                  2339
# AMT_INCOME_TOTAL                2548
# COMMONAREA_MODE                 3128
# COMMONAREA_AVG                  3181
# COMMONAREA_MEDI                 3202
# NONLIVINGAREA_AVG               3290
# NONLIVINGAREA_MEDI              3323
# NONLIVINGAREA_MODE              3327
# LANDAREA_AVG                    3527
# LANDAREA_MEDI                   3560
# LANDAREA_MODE                   3563
# BASEMENTAREA_MEDI               3772
# DAYS_LAST_PHONE_CHANGE          3773
# BASEMENTAREA_AVG                3780
# BASEMENTAREA_MODE               3841
# TOTALAREA_MODE                  5116
# LIVINGAREA_AVG                  5199
# dtype: int64

# %%
print(df['TARGET'].value_counts(normalize=True))
# Out:
# TARGET
# 0    0.919271
# 1    0.080729
# Name: proportion, dtype: float64

# %%
# Numeric summary + skew
num = df.select_dtypes(include=["number"])
desc = num.drop(columns=['SK_ID_CURR', 'TARGET']).describe().T
desc["skew"] = num.skew().round(3)
desc.head(20)
# Out:
#                                 count           mean            std  \
# CNT_CHILDREN                 307511.0       0.417052       0.722121
# AMT_INCOME_TOTAL             307511.0  168797.919297  237123.146279
# AMT_CREDIT                   307511.0  599025.999706  402490.776996
# AMT_ANNUITY                  307499.0   27108.573909   14493.737315
# AMT_GOODS_PRICE              307233.0  538396.207429  369446.460540
# REGION_POPULATION_RELATIVE   307511.0       0.020868       0.013831
# DAYS_BIRTH                   307511.0  -16036.995067    4363.988632
# DAYS_EMPLOYED                307511.0   63815.045904  141275.766519
# DAYS_REGISTRATION            307511.0   -4986.120328    3522.886321
# DAYS_ID_PUBLISH              307511.0   -2994.202373    1509.450419
# OWN_CAR_AGE                  104582.0      12.061091      11.944812
# FLAG_MOBIL                   307511.0       0.999997       0.001803
# FLAG_EMP_PHONE               307511.0       0.819889       0.384280
# FLAG_WORK_PHONE              307511.0       0.199368       0.399526
# FLAG_CONT_MOBILE             307511.0       0.998133       0.043164
# FLAG_PHONE                   307511.0       0.281066       0.449521
# FLAG_EMAIL                   307511.0       0.056720       0.231307
# CNT_FAM_MEMBERS              307509.0       2.152665       0.910682
# REGION_RATING_CLIENT         307511.0       2.052463       0.509034
# REGION_RATING_CLIENT_W_CITY  307511.0       2.031521       0.502737
#
#                                      min            25%           50%  \
# CNT_CHILDREN                     0.00000       0.000000       0.00000
# AMT_INCOME_TOTAL             25650.00000  112500.000000  147150.00000
# AMT_CREDIT                   45000.00000  270000.000000  513531.00000
# AMT_ANNUITY                   1615.50000   16524.000000   24903.00000
# AMT_GOODS_PRICE              40500.00000  238500.000000  450000.00000
# REGION_POPULATION_RELATIVE       0.00029       0.010006       0.01885
# DAYS_BIRTH                  -25229.00000  -19682.000000  -15750.00000
# DAYS_EMPLOYED               -17912.00000   -2760.000000   -1213.00000
# DAYS_REGISTRATION           -24672.00000   -7479.500000   -4504.00000
# DAYS_ID_PUBLISH              -7197.00000   -4299.000000   -3254.00000
# OWN_CAR_AGE                      0.00000       5.000000       9.00000
# FLAG_MOBIL                       0.00000       1.000000       1.00000
# FLAG_EMP_PHONE                   0.00000       1.000000       1.00000
# FLAG_WORK_PHONE                  0.00000       0.000000       0.00000
# FLAG_CONT_MOBILE                 0.00000       1.000000       1.00000
# FLAG_PHONE                       0.00000       0.000000       0.00000
# FLAG_EMAIL                       0.00000       0.000000       0.00000
# CNT_FAM_MEMBERS                  1.00000       2.000000       2.00000
# REGION_RATING_CLIENT             1.00000       2.000000       2.00000
# REGION_RATING_CLIENT_W_CITY      1.00000       2.000000       2.00000
#
#                                        75%           max     skew
# CNT_CHILDREN                      1.000000  1.900000e+01    1.975
# AMT_INCOME_TOTAL             202500.000000  1.170000e+08  391.560
# AMT_CREDIT                   808650.000000  4.050000e+06    1.235
# AMT_ANNUITY                   34596.000000  2.580255e+05    1.580
# AMT_GOODS_PRICE              679500.000000  4.050000e+06    1.349
# REGION_POPULATION_RELATIVE        0.028663  7.250800e-02    1.488
# DAYS_BIRTH                   -12413.000000 -7.489000e+03   -0.116
# DAYS_EMPLOYED                  -289.000000  3.652430e+05    1.664
# DAYS_REGISTRATION             -2010.000000  0.000000e+00   -0.591
# DAYS_ID_PUBLISH               -1720.000000  0.000000e+00    0.349
# OWN_CAR_AGE                      15.000000  9.100000e+01    2.745
# FLAG_MOBIL                        1.000000  1.000000e+00 -554.537
# FLAG_EMP_PHONE                    1.000000  1.000000e+00   -1.665
# FLAG_WORK_PHONE                   0.000000  1.000000e+00    1.505
# FLAG_CONT_MOBILE                  1.000000  1.000000e+00  -23.081
# FLAG_PHONE                        1.000000  1.000000e+00    0.974
# FLAG_EMAIL                        0.000000  1.000000e+00    3.833
# CNT_FAM_MEMBERS                   3.000000  2.000000e+01    0.988
# REGION_RATING_CLIENT              2.000000  3.000000e+00    0.087
# REGION_RATING_CLIENT_W_CITY       2.000000  3.000000e+00    0.060

# %%
# Age/work features diagnostic
if "DAYS_BIRTH" in df.columns:
    df["AGE_YEARS"] = (-df["DAYS_BIRTH"] / 365).astype(int)
    print("\nAGE_YEARS range:", df["AGE_YEARS"].min(), df["AGE_YEARS"].max())
    # target rate by age bins
    if "TARGET" in df.columns:
        bins = pd.cut(df["AGE_YEARS"], bins=10)
        age_rate = df.groupby(bins, observed=True)["TARGET"].mean().round(4)
        print("\nTARGET rate by age bin:\n", age_rate)
# Out:
# AGE_YEARS range: 20 69
#
# TARGET rate by age bin:
#  AGE_YEARS
# (19.951, 24.9]    0.1231
# (24.9, 29.8]      0.1114
# (29.8, 34.7]      0.1029
# (34.7, 39.6]      0.0893
# (39.6, 44.5]      0.0786
# (44.5, 49.4]      0.0742
# (49.4, 54.3]      0.0670
# (54.3, 59.2]      0.0553
# (59.2, 64.1]      0.0528
# (64.1, 69.0]      0.0372
# Name: TARGET, dtype: float64

# %%
# DAYS_EMPLOYED sentinel check (Kaggle dataset uses 365243)
if "DAYS_EMPLOYED" in df.columns:
    sentinel = (df["DAYS_EMPLOYED"] > 0).sum()
    sentinel365 = (df["DAYS_EMPLOYED"] == 365243).sum()
    print("\nDAYS_EMPLOYED > 0 count:", int(sentinel))
    print("DAYS_EMPLOYED == 365243 count:", int(sentinel365))
    print("DAYS_EMPLOYED describe:\n", df["DAYS_EMPLOYED"].describe())
# Out:
# DAYS_EMPLOYED > 0 count: 55374
# DAYS_EMPLOYED == 365243 count: 55374
# DAYS_EMPLOYED describe:
#  count    307511.000000
# mean      63815.045904
# std      141275.766519
# min      -17912.000000
# 25%       -2760.000000
# 50%       -1213.000000
# 75%        -289.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %%
# Binary-like columns detection (0/1)
binary_cols = [c for c in df.columns if set(df[c].dropna().unique()).issubset({0, 1})]
print(f"\nBinary-like columns (0/1) count {len(binary_cols)}:", binary_cols)
# Out:
# Binary-like columns (0/1) count 33: ['TARGET', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']

# %%
# Quick anomaly checks: extreme values for amounts
for col in ["AMT_INCOME_TOTAL", "AMT_CREDIT", "AMT_ANNUITY", "AMT_GOODS_PRICE"]:
    if col in df.columns:
        s = df[col].dropna()
        print(f"\n{col}: min={s.min():.2f}, 1%={s.quantile(0.01):.2f}, 99%={s.quantile(0.99):.2f}, max={s.max():.2f}")
# Out:
# AMT_INCOME_TOTAL: min=25650.00, 1%=45000.00, 99%=472500.00, max=117000000.00
#
# AMT_CREDIT: min=45000.00, 1%=76410.00, 99%=1854000.00, max=4050000.00
#
# AMT_ANNUITY: min=1615.50, 1%=6182.91, 99%=70006.50, max=258025.50
#
# AMT_GOODS_PRICE: min=40500.00, 1%=67500.00, 99%=1800000.00, max=4050000.00
